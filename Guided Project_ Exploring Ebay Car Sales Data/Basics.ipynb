# %% [markdown]
# we'll work with a dataset of used cars from eBay Kleinanzeigen, a classifieds section of the German eBay website. The aim of this project is to clean the data and analyze the included used car listings.

# %%
import pandas as pd
import numpy as np
autos=pd.read_csv('autos.csv', encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %%
autos.head()
# Out:
#            dateCrawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offerType   price   abtest vehicleType  yearOfRegistration  \
# 0  privat   Angebot  $5,000  control         bus                2004
# 1  privat   Angebot  $8,500  control   limousine                1997
# 2  privat   Angebot  $8,990     test   limousine                2009
# 3  privat   Angebot  $4,350  control  kleinwagen                2007
# 4  privat   Angebot  $1,350     test       kombi                2003
#
#      gearbox  powerPS   model   odometer  monthOfRegistration fuelType  \
# ...

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename(columns={"yearOfRegistration":"registration_year", "monthOfRegistration":"registration_month", "notRepairedDamage":"unrepaired_damage", "dateCreated":"ad_created"}, inplace=True)

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'registration_year', 'gearbox', 'powerPS', 'model',
#        'odometer', 'registration_month', 'fuelType', 'brand',
#        'unrepaired_damage', 'ad_created', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename(columns={"yearOfRegistration":"registration_year", "monthOfRegistration":"registration_month", "notRepairedDamage":"unrepaired_damage", "dateCreated":"ad_created", "dateCrawled":"date_crawled", "offerType":"offer_type", "vehicleType":"vehicle_type", "powerPS":"power_ps", "fuelType":"fuel_type", "notRepariedDamage":"not_repaired_damage", "nrOfPictures":"no_of_pictures", "postalCode":"postal_code", "lastSeen":"last_seen" }, inplace=True)

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'no_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# Changed the column names using dataframe.rename attritbute to make them easily readable in camel case.

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  no_of_pictures  \
# count       50000.000000  50000.000000        50000.000000         50000.0
# mean         2005.073280    116.355920            5.723360             0.0
# std           105.712813    209.216627            3.711984             0.0
# min          1000.000000      0.000000            0.000000             0.0
# 25%          1999.000000     70.000000            3.000000             0.0
# 50%          2003.000000    105.000000            6.000000             0.0
# 75%          2008.000000    150.000000            9.000000             0.0
# max          9999.000000  17700.000000           12.000000             0.0
#
#         postal_code
# count  50000.000000
# mean   50813.627300
# std    25779.747957
# min     1067.000000
# 25%    30451.000000
# 50%    49577.000000
# 75%    71540.000000
# max    99998.000000

# %% [markdown]
# There are no pictures in any of the column, so we can drop the number of pictures column. Price and Odometer columns, which are supposed to be numerical but in the dataframe they are strings. Apart from year of registration, I feel that a new column indicating the age of cars (considering 2019 as the current year) will help decide.

# %%
autos["price"]=autos["price"].str.replace("$","").str.replace(",","").astype(int)

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps  registration_month  \
# count  5.000000e+04       50000.000000  50000.000000        50000.000000
# mean   9.840044e+03        2005.073280    116.355920            5.723360
# std    4.811044e+05         105.712813    209.216627            3.711984
# min    0.000000e+00        1000.000000      0.000000            0.000000
# 25%    1.100000e+03        1999.000000     70.000000            3.000000
# 50%    2.950000e+03        2003.000000    105.000000            6.000000
# 75%    7.200000e+03        2008.000000    150.000000            9.000000
# max    1.000000e+08        9999.000000  17700.000000           12.000000
#
#        no_of_pictures   postal_code
# count         50000.0  50000.000000
# mean              0.0  50813.627300
# std               0.0  25779.747957
# min               0.0   1067.000000
# 25%               0.0  30451.000000
# 50%               0.0  49577.000000
# 75%               0.0  71540.000000
# ...

# %%
autos["odometer"]=autos["odometer"].str.replace(",","").str.replace("km","").astype(int)

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps       odometer  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   9.840044e+03        2005.073280    116.355920  125732.700000
# std    4.811044e+05         105.712813    209.216627   40042.211706
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        9999.000000  17700.000000  150000.000000
#
#        registration_month  no_of_pictures   postal_code
# count        50000.000000         50000.0  50000.000000
# mean             5.723360             0.0  50813.627300
# std              3.711984             0.0  25779.747957
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30451.000000
# ...

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type  price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot   5000  control          bus               2004
# 1  privat    Angebot   8500  control    limousine               1997
# 2  privat    Angebot   8990     test    limousine               2009
# 3  privat    Angebot   4350  control   kleinwagen               2007
# 4  privat    Angebot   1350     test        kombi               2003
#
#      gearbox  power_ps   model  odometer  registration_month fuel_type  \
# ...

# %%
autos.rename(columns={"odometer":"odometer_km"})
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'no_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %% [markdown]
# You might have noticed that "odometer" column's name is unchanged because I did not change that in place (inplace =True). I changed it in the next cell and printed the column names. Just a point to remember§

# %%
autos.rename(columns={"odometer":"odometer_km"}, inplace=True)

# %%
autos.columns
# Out:
# Index(['date_crawled', 'name', 'seller', 'offer_type', 'price', 'abtest',
#        'vehicle_type', 'registration_year', 'gearbox', 'power_ps', 'model',
#        'odometer_km', 'registration_month', 'fuel_type', 'brand',
#        'unrepaired_damage', 'ad_created', 'no_of_pictures', 'postal_code',
#        'last_seen'],
#       dtype='object')

# %%
autos.describe()
# Out:
#               price  registration_year      power_ps    odometer_km  \
# count  5.000000e+04       50000.000000  50000.000000   50000.000000
# mean   9.840044e+03        2005.073280    116.355920  125732.700000
# std    4.811044e+05         105.712813    209.216627   40042.211706
# min    0.000000e+00        1000.000000      0.000000    5000.000000
# 25%    1.100000e+03        1999.000000     70.000000  125000.000000
# 50%    2.950000e+03        2003.000000    105.000000  150000.000000
# 75%    7.200000e+03        2008.000000    150.000000  150000.000000
# max    1.000000e+08        9999.000000  17700.000000  150000.000000
#
#        registration_month  no_of_pictures   postal_code
# count        50000.000000         50000.0  50000.000000
# mean             5.723360             0.0  50813.627300
# std              3.711984             0.0  25779.747957
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30451.000000
# ...

# %%
autos["odometer_km"].unique()
# Out:
# array([150000,  70000,  50000,  80000,  10000,  30000, 125000,  90000,
#         20000,  60000,   5000, 100000,  40000])

# %%
autos["odometer_km"].unique().shape
# Out:
# (13,)

# %%
type(autos["odometer_km"].unique())
# Out:
# numpy.ndarray

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000    32424
# 125000     5170
# 100000     2169
# 90000      1757
# 80000      1436
# 70000      1230
# 60000      1164
# 50000      1027
# 5000        967
# 40000       819
# 30000       789
# 20000       784
# 10000       264
# Name: odometer_km, dtype: int64

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %%
autos["price"].value_counts().shape
# Out:
# (2357,)

# %%
autos["price"].value_counts().head(100)
# Out:
# 0        1421
# 500       781
# 1500      734
# 2500      643
# 1000      639
# 1200      639
# 600       531
# 800       498
# 3500      498
# 2000      460
# 999       434
# 750       433
# 900       420
# 650       419
# 850       410
# 700       395
# 4500      394
# 300       384
# 2200      382
# 950       379
# 1100      376
# 1300      371
# 3000      365
# 550       356
# 1800      355
# 5500      340
# 1250      335
# 350       335
# 1600      327
# 1999      322
#          ...
# 4999      174
# 2950      173
# 2750      169
# 6900      165
# 7000      165
# 8000      161
# 1499      157
# 5200      156
# 1         156
# 7900      156
# 3700      155
# 1550      150
# 990       147
# 2250      147
# 11500     145
# 8900      144
# 12500     142
# 5999      140
# 3400      137
# 2499      136
# 1299      135
# 9900      135
# 3950      135
# 2990      134
# 100       134
# 3100      133
# 4300      132
# 9999      131
# 2850      131
# 13500     130
# ...

# %%
autos["odometer_km"].value_counts().sort_index(ascending=True)
# Out:
# 5000        967
# 10000       264
# 20000       784
# 30000       789
# 40000       819
# 50000      1027
# 60000      1164
# 70000      1230
# 80000      1436
# 90000      1757
# 100000     2169
# 125000     5170
# 150000    32424
# Name: odometer_km, dtype: int64

# %%
autos["price"].value_counts().sort_index(ascending=False).head(100)
# Out:
# 99999999    1
# 27322222    1
# 12345678    3
# 11111111    2
# 10000000    1
# 3890000     1
# 1300000     1
# 1234566     1
# 999999      2
# 999990      1
# 350000      1
# 345000      1
# 299000      1
# 295000      1
# 265000      1
# 259000      1
# 250000      1
# 220000      1
# 198000      1
# 197000      1
# 194000      1
# 190000      1
# 180000      1
# 175000      1
# 169999      1
# 169000      1
# 163991      1
# 163500      1
# 155000      1
# 151990      1
#            ..
# 75900       1
# 75000       1
# 74999       2
# 74900       3
# 73996       1
# 73900       1
# 73500       1
# 72900       1
# 72600       1
# 72500       1
# 71000       1
# 70850       1
# 70000       1
# 69999       1
# 69997       1
# 69993       1
# 69900       1
# 69500       1
# 68900       1
# 68750       1
# 68500       1
# 68300       1
# 68000       1
# 67911       1
# 67000       1
# 66964       1
# 66500       1
# 65990       1
# 65700       1
# 65699       1
# ...

# %% [markdown]
# If I sort the values in reverse order, we see that the values above 350,000 are not valid values, they were just random or outlier values. In the next cell, I used the price value between 500 and 351000. When inspecting closer, the price could start from 1 usd, as ebay is about auction. To avoid excluding such data, I used the value beteen 1 and 351000.
#
# For odometer values, it is not necessary. There is no unreasonably high or invalid values. There are many high mileage cars, which is understandable on an auction site.

# %%
autos["price"].value_counts().sort_index(ascending=True).head(300)
# Out:
# 0       1421
# 1        156
# 2          3
# 3          1
# 5          2
# 8          1
# 9          1
# 10         7
# 11         2
# 12         3
# 13         2
# 14         1
# 15         2
# 17         3
# 18         1
# 20         4
# 25         5
# 29         1
# 30         7
# 35         1
# 40         6
# 45         4
# 47         1
# 49         4
# 50        49
# 55         2
# 59         1
# 60         9
# 65         5
# 66         1
#         ...
# 1100     376
# 1111      39
# 1112       1
# 1119       1
# 1120       2
# 1149      10
# 1150     226
# 1169       1
# 1170       1
# 1180       4
# 1189       1
# 1190      37
# 1195       1
# 1199     126
# 1200     639
# 1201       2
# 1209       1
# 1212       2
# 1221       1
# 1222       3
# 1234       3
# 1240       2
# 1247       1
# 1249       4
# 1250     335
# 1265       1
# 1270       4
# 1275       1
# 1280      12
# 1285       3
# Name: price, Length: 300, dtype: int64

# %%
autos[autos["price"].between(500,351000)]
# Out:
#               date_crawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# 12     2016-03-31 19:48:22  Smart_smart_fortwo_coupe_softouch_pure_MHD_Pan...
# 13     2016-03-23 10:48:32                                 Audi_A3_1.6_tuning
# ...

# %%
autos=autos[autos["price"].between(1,351000)]

# %%
autos.describe()
# Out:
#                price  registration_year      power_ps    odometer_km  \
# count   48565.000000       48565.000000  48565.000000   48565.000000
# mean     5888.935591        2004.755421    117.197158  125770.101925
# std      9059.854754          88.643887    200.649618   39788.636804
# min         1.000000        1000.000000      0.000000    5000.000000
# 25%      1200.000000        1999.000000     71.000000  125000.000000
# 50%      3000.000000        2004.000000    107.000000  150000.000000
# 75%      7490.000000        2008.000000    150.000000  150000.000000
# max    350000.000000        9999.000000  17700.000000  150000.000000
#
#        registration_month  no_of_pictures   postal_code
# count        48565.000000         48565.0  48565.000000
# mean             5.782251             0.0  50975.745207
# std              3.685595             0.0  25746.968398
# min              0.000000             0.0   1067.000000
# 25%              3.000000             0.0  30657.000000
# ...

# %%
autos["no_of_pictures"].unique()
# Out:
# array([0])

# %%
autos["no_of_pictures"].value_counts()
# Out:
# 0    48565
# Name: no_of_pictures, dtype: int64

# %%
autos["seller"].value_counts()
# Out:
# privat        48564
# gewerblich        1
# Name: seller, dtype: int64

# %%
autos["offer_type"].value_counts()
# Out:
# Angebot    48565
# Name: offer_type, dtype: int64

# %% [markdown]
# As you can see, the number of pictures column is zero everywhere, so there is no additional value in including those columns. In seller information, you can see that they are all private except one commercial seller. Offer type column also has only one value. I decided to remove these columns.

# %%
autos = autos.drop(["no_of_pictures", "seller", "offer_type"], axis=1)

# %%
autos.head()
# Out:
#           date_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    price   abtest vehicle_type  registration_year    gearbox  power_ps  \
# 0   5000  control          bus               2004    manuell       158
# 1   8500  control    limousine               1997  automatik       286
# 2   8990     test    limousine               2009    manuell       102
# 3   4350  control   kleinwagen               2007  automatik        71
# 4   1350     test        kombi               2003    manuell         0
#
#     model  odometer_km  registration_month fuel_type       brand  \
# ...

# %%
autos[["date_crawled", "ad_created", "last_seen"]][0:5]
# Out:
#           date_crawled           ad_created            last_seen
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50

# %%
autos["date_crawled"].value_counts().sort_index()
# Out:
# 2016-03-05 14:06:30    1
# 2016-03-05 14:06:40    1
# 2016-03-05 14:07:04    1
# 2016-03-05 14:07:08    1
# 2016-03-05 14:07:21    1
# 2016-03-05 14:07:26    1
# 2016-03-05 14:07:40    1
# 2016-03-05 14:07:45    1
# 2016-03-05 14:08:00    2
# 2016-03-05 14:08:05    2
# 2016-03-05 14:08:27    1
# 2016-03-05 14:08:42    1
# 2016-03-05 14:09:02    2
# 2016-03-05 14:09:05    1
# 2016-03-05 14:09:20    1
# 2016-03-05 14:09:22    1
# 2016-03-05 14:09:38    1
# 2016-03-05 14:09:46    1
# 2016-03-05 14:09:56    1
# 2016-03-05 14:09:57    1
# 2016-03-05 14:09:58    2
# 2016-03-05 14:10:18    1
# 2016-03-05 14:10:20    1
# 2016-03-05 14:10:46    1
# 2016-03-05 14:11:03    1
# 2016-03-05 14:11:05    1
# 2016-03-05 14:11:14    1
# 2016-03-05 14:11:15    1
# 2016-03-05 14:11:25    1
# 2016-03-05 14:11:40    1
#                       ..
# 2016-04-07 10:36:17    1
# 2016-04-07 10:36:19    1
# 2016-04-07 10:36:24    1
# 2016-04-07 10:36:25    1
# 2016-04-07 10:36:35    1
# 2016-04-07 10:36:36    1
# ...

# %%
autos["date_crawled"].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05 14:06:30    0.000021
# 2016-03-05 14:06:40    0.000021
# 2016-03-05 14:07:04    0.000021
# 2016-03-05 14:07:08    0.000021
# 2016-03-05 14:07:21    0.000021
# 2016-03-05 14:07:26    0.000021
# 2016-03-05 14:07:40    0.000021
# 2016-03-05 14:07:45    0.000021
# 2016-03-05 14:08:00    0.000041
# 2016-03-05 14:08:05    0.000041
# 2016-03-05 14:08:27    0.000021
# 2016-03-05 14:08:42    0.000021
# 2016-03-05 14:09:02    0.000041
# 2016-03-05 14:09:05    0.000021
# 2016-03-05 14:09:20    0.000021
# 2016-03-05 14:09:22    0.000021
# 2016-03-05 14:09:38    0.000021
# 2016-03-05 14:09:46    0.000021
# 2016-03-05 14:09:56    0.000021
# 2016-03-05 14:09:57    0.000021
# 2016-03-05 14:09:58    0.000041
# 2016-03-05 14:10:18    0.000021
# 2016-03-05 14:10:20    0.000021
# 2016-03-05 14:10:46    0.000021
# 2016-03-05 14:11:03    0.000021
# 2016-03-05 14:11:05    0.000021
# 2016-03-05 14:11:14    0.000021
# 2016-03-05 14:11:15    0.000021
# 2016-03-05 14:11:25    0.000021
# ...

# %%
autos["date_crawled"].unique().shape
# Out:
# (46882,)

# %% [markdown]
# The ads are crawled from dates between 5th March 2016 to 7th April 2016. There are 46882 values and each value is 0.0021 percentage.

# %%
autos["ad_created"].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2015-06-11 00:00:00    0.000021
# 2015-08-10 00:00:00    0.000021
# 2015-09-09 00:00:00    0.000021
# 2015-11-10 00:00:00    0.000021
# 2015-12-05 00:00:00    0.000021
# 2015-12-30 00:00:00    0.000021
# 2016-01-03 00:00:00    0.000021
# 2016-01-07 00:00:00    0.000021
# 2016-01-10 00:00:00    0.000041
# 2016-01-13 00:00:00    0.000021
# 2016-01-14 00:00:00    0.000021
# 2016-01-16 00:00:00    0.000021
# 2016-01-22 00:00:00    0.000021
# 2016-01-27 00:00:00    0.000062
# 2016-01-29 00:00:00    0.000021
# 2016-02-01 00:00:00    0.000021
# 2016-02-02 00:00:00    0.000041
# 2016-02-05 00:00:00    0.000041
# 2016-02-07 00:00:00    0.000021
# 2016-02-08 00:00:00    0.000021
# 2016-02-09 00:00:00    0.000021
# 2016-02-11 00:00:00    0.000021
# 2016-02-12 00:00:00    0.000041
# 2016-02-14 00:00:00    0.000041
# 2016-02-16 00:00:00    0.000021
# 2016-02-17 00:00:00    0.000021
# 2016-02-18 00:00:00    0.000041
# 2016-02-19 00:00:00    0.000062
# 2016-02-20 00:00:00    0.000041
# ...

# %% [markdown]
# 46882 ads are created on 76 days between 11th June 2015 to 7th April 2016. 0.002 percentage of ads are created on some days and more than 60% ads were created in the last 3 weeks.

# %%
autos["last_seen"].str[:10].value_counts(normalize=True, dropna=False).sort_index()
# Out:
# 2016-03-05    0.001071
# 2016-03-06    0.004324
# 2016-03-07    0.005395
# 2016-03-08    0.007413
# 2016-03-09    0.009595
# 2016-03-10    0.010666
# 2016-03-11    0.012375
# 2016-03-12    0.023783
# 2016-03-13    0.008895
# 2016-03-14    0.012602
# 2016-03-15    0.015876
# 2016-03-16    0.016452
# 2016-03-17    0.028086
# 2016-03-18    0.007351
# 2016-03-19    0.015834
# 2016-03-20    0.020653
# 2016-03-21    0.020632
# 2016-03-22    0.021373
# 2016-03-23    0.018532
# 2016-03-24    0.019767
# 2016-03-25    0.019211
# 2016-03-26    0.016802
# 2016-03-27    0.015649
# 2016-03-28    0.020859
# 2016-03-29    0.022341
# 2016-03-30    0.024771
# 2016-03-31    0.023783
# 2016-04-01    0.022794
# 2016-04-02    0.024915
# 2016-04-03    0.025203
# 2016-04-04    0.024483
# 2016-04-05    0.124761
# 2016-04-06    0.221806
# 2016-04-07    0.131947
# Name: last_seen, dtype: float64

# %% [markdown]
# The ads were last seen from dates between 5th March 2016 to 7th April 2016. There are 38474 values and 60% of the ads were last seen or removed.

# %%
autos["registration_year"].describe()
# Out:
# count    48565.000000
# mean      2004.755421
# std         88.643887
# min       1000.000000
# 25%       1999.000000
# 50%       2004.000000
# 75%       2008.000000
# max       9999.000000
# Name: registration_year, dtype: float64

# %%
autos["registration_year"].value_counts()
# Out:
# 2000    3156
# 2005    2936
# 1999    2897
# 2004    2703
# 2003    2699
# 2006    2670
# 2001    2636
# 2002    2486
# 1998    2363
# 2007    2277
# 2008    2215
# 2009    2085
# 1997    1951
# 2011    1623
# 2010    1589
# 2017    1392
# 1996    1373
# 2012    1310
# 1995    1227
# 2016    1220
# 2013     803
# 2014     663
# 1994     629
# 2018     470
# 1993     425
# 2015     392
# 1992     370
# 1990     347
# 1991     339
# 1989     174
#         ...
# 1950       3
# 9999       3
# 1800       2
# 1951       2
# 1941       2
# 1934       2
# 1954       2
# 1957       2
# 1955       2
# 2019       2
# 1001       1
# 1939       1
# 4500       1
# 1953       1
# 1111       1
# 4800       1
# 5911       1
# 1943       1
# 1938       1
# 1929       1
# 2800       1
# 6200       1
# 4100       1
# 8888       1
# 1927       1
# 9000       1
# 1948       1
# 1000       1
# 1931       1
# 1952       1
# Name: registration_year, Length: 95, dtype: int64

# %%
autos["registration_year"].value_counts().sort_index().head(95)
# Out:
# 1000       1
# 1001       1
# 1111       1
# 1800       2
# 1910       5
# 1927       1
# 1929       1
# 1931       1
# 1934       2
# 1937       4
# 1938       1
# 1939       1
# 1941       2
# 1943       1
# 1948       1
# 1950       3
# 1951       2
# 1952       1
# 1953       1
# 1954       2
# 1955       2
# 1956       4
# 1957       2
# 1958       4
# 1959       6
# 1960      23
# 1961       6
# 1962       4
# 1963       8
# 1964      12
#         ...
# 2000    3156
# 2001    2636
# 2002    2486
# 2003    2699
# 2004    2703
# 2005    2936
# 2006    2670
# 2007    2277
# 2008    2215
# 2009    2085
# 2010    1589
# 2011    1623
# 2012    1310
# 2013     803
# 2014     663
# 2015     392
# 2016    1220
# 2017    1392
# 2018     470
# 2019       2
# 2800       1
# 4100       1
# 4500       1
# 4800       1
# 5000       4
# 5911       1
# 6200       1
# 8888       1
# 9000       1
# 9999       3
# Name: registration_year, Length: 95, dtype: int64

# %% [markdown]
# There are some invalid values because the first production automobile by Benz was from 1885. We need to take values only from 1910. The ads were crawled latest on 7th April 2016, so the year registered cannot be more than that. We can drop values from 2017 onwards. The number of cars advertised are in 2 digits for years between 1960 to 1987. After that, it is in 3 digits, i.e atleast 100 cars for that model year.  From 1995 onwards, there are more than 1000 cars listed per year till 2012.

# %%
autos=autos[autos["registration_year"].between(1910,2016)]

# %%
autos["registration_year"].value_counts(normalize=True).sort_index()
# Out:
# 1910    0.000107
# 1927    0.000021
# 1929    0.000021
# 1931    0.000021
# 1934    0.000043
# 1937    0.000086
# 1938    0.000021
# 1939    0.000021
# 1941    0.000043
# 1943    0.000021
# 1948    0.000021
# 1950    0.000064
# 1951    0.000043
# 1952    0.000021
# 1953    0.000021
# 1954    0.000043
# 1955    0.000043
# 1956    0.000086
# 1957    0.000043
# 1958    0.000086
# 1959    0.000129
# 1960    0.000493
# 1961    0.000129
# 1962    0.000086
# 1963    0.000171
# 1964    0.000257
# 1965    0.000364
# 1966    0.000471
# 1967    0.000557
# 1968    0.000557
#           ...
# 1987    0.001542
# 1988    0.002892
# 1989    0.003727
# 1990    0.007433
# 1991    0.007262
# 1992    0.007926
# 1993    0.009104
# 1994    0.013474
# 1995    0.026285
# 1996    0.029412
# 1997    0.041794
# 1998    0.050620
# 1999    0.062060
# 2000    0.067608
# 2001    0.056468
# 2002    0.053255
# 2003    0.057818
# 2004    0.057904
# 2005    0.062895
# 2006    0.057197
# 2007    0.048778
# ...

# %% [markdown]
# Most sold cars are from year 2000 and then 2005 comes next. More than 70% of the cars sold are from year 2000

# %%
autos["brand"].unique()
# Out:
# array(['peugeot', 'bmw', 'volkswagen', 'smart', 'ford', 'chrysler',
#        'seat', 'renault', 'mercedes_benz', 'audi', 'sonstige_autos',
#        'opel', 'mazda', 'porsche', 'mini', 'toyota', 'dacia', 'nissan',
#        'jeep', 'saab', 'volvo', 'mitsubishi', 'jaguar', 'fiat', 'skoda',
#        'subaru', 'kia', 'citroen', 'chevrolet', 'hyundai', 'honda',
#        'daewoo', 'suzuki', 'trabant', 'land_rover', 'alfa_romeo', 'lada',
#        'rover', 'daihatsu', 'lancia'], dtype=object)

# %%
unique_brand_counts={}
brand_list=autos["brand"].unique()
print(brand_list.shape)
type(brand_list)
autos["brand"].value_counts(normalize=True).sort_index()
autos["brand"].value_counts()
# Out:
# (40,)
# volkswagen        9862
# bmw               5137
# opel              5022
# mercedes_benz     4503
# audi              4041
# ford              3263
# renault           2201
# peugeot           1393
# fiat              1197
# seat               853
# skoda              766
# nissan             713
# mazda              709
# smart              661
# citroen            654
# toyota             593
# hyundai            468
# sonstige_autos     458
# volvo              427
# mini               409
# mitsubishi         384
# honda              366
# kia                330
# alfa_romeo         310
# porsche            286
# suzuki             277
# chevrolet          266
# chrysler           164
# dacia              123
# daihatsu           117
# jeep               106
# subaru             100
# land_rover          98
# saab                77
# jaguar              73
# daewoo              70
# trabant             65
# rover               62
# lancia              50
# ...

# %%
autos["brand"].value_counts().index
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat', 'skoda', 'nissan', 'mazda', 'smart',
#        'citroen', 'toyota', 'hyundai', 'sonstige_autos', 'volvo', 'mini',
#        'mitsubishi', 'honda', 'kia', 'alfa_romeo', 'porsche', 'suzuki',
#        'chevrolet', 'chrysler', 'dacia', 'daihatsu', 'jeep', 'subaru',
#        'land_rover', 'saab', 'jaguar', 'daewoo', 'trabant', 'rover', 'lancia',
#        'lada'],
#       dtype='object')

# %%
brands_sold=autos["brand"].value_counts()
brands_index=autos["brand"].value_counts().index

# %%
brands_index[0]
# Out:
# 'volkswagen'

# %%
brands_sold[0]
# Out:
# 9862

# %%
brands_index_sel=brands_index[:20]
brands_sold_sel=brands_sold[:20]

# %%
brands_sold_sel
# Out:
# volkswagen        9862
# bmw               5137
# opel              5022
# mercedes_benz     4503
# audi              4041
# ford              3263
# renault           2201
# peugeot           1393
# fiat              1197
# seat               853
# skoda              766
# nissan             713
# mazda              709
# smart              661
# citroen            654
# toyota             593
# hyundai            468
# sonstige_autos     458
# volvo              427
# mini               409
# Name: brand, dtype: int64

# %%
brands_sold.sum()
# Out:
# 46681

# %% [raw]
# (5/100)*brands_sold.sum()

# %%
46681*0.05
# Out:
# 2334.05

# %% [markdown]
# I have selected the top twenty brands. If I use the criteria of brands that are over 5%, I can have only 6 values.

# %%
brands_index_sel
# Out:
# Index(['volkswagen', 'bmw', 'opel', 'mercedes_benz', 'audi', 'ford', 'renault',
#        'peugeot', 'fiat', 'seat', 'skoda', 'nissan', 'mazda', 'smart',
#        'citroen', 'toyota', 'hyundai', 'sonstige_autos', 'volvo', 'mini'],
#       dtype='object')

# %%
unique_brand_counts={}
for b in brands_sold_sel:
    print(b)
# Out:
# 9862
# 5137
# 5022
# 4503
# 4041
# 3263
# 2201
# 1393
# 1197
# 853
# 766
# 713
# 709
# 661
# 654
# 593
# 468
# 458
# 427
# 409

# %%
for b in brands_index_sel:
    print(b)
# Out:
# volkswagen
# bmw
# opel
# mercedes_benz
# audi
# ford
# renault
# peugeot
# fiat
# seat
# skoda
# nissan
# mazda
# smart
# citroen
# toyota
# hyundai
# sonstige_autos
# volvo
# mini

# %%
unique_brand_counts={}
for b in brands_index_sel:
    unique_brand_counts[b]=int(autos.loc[autos["brand"]==b, "price"].mean())

# %%
unique_brand_counts
# Out:
# {'audi': 9336,
#  'bmw': 8332,
#  'citroen': 3779,
#  'fiat': 2813,
#  'ford': 3749,
#  'hyundai': 5365,
#  'mazda': 4112,
#  'mercedes_benz': 8628,
#  'mini': 10613,
#  'nissan': 4743,
#  'opel': 2975,
#  'peugeot': 3094,
#  'renault': 2474,
#  'seat': 4397,
#  'skoda': 6368,
#  'smart': 3580,
#  'sonstige_autos': 12338,
#  'toyota': 5167,
#  'volkswagen': 5402,
#  'volvo': 4946}

# %%
sorted_brand = sorted((value, key) for (key,value) in unique_brand_counts.items())

# %%
sorted_brand
# Out:
# [(2474, 'renault'),
#  (2813, 'fiat'),
#  (2975, 'opel'),
#  (3094, 'peugeot'),
#  (3580, 'smart'),
#  (3749, 'ford'),
#  (3779, 'citroen'),
#  (4112, 'mazda'),
#  (4397, 'seat'),
#  (4743, 'nissan'),
#  (4946, 'volvo'),
#  (5167, 'toyota'),
#  (5365, 'hyundai'),
#  (5402, 'volkswagen'),
#  (6368, 'skoda'),
#  (8332, 'bmw'),
#  (8628, 'mercedes_benz'),
#  (9336, 'audi'),
#  (10613, 'mini'),
#  (12338, 'sonstige_autos')]

# %% [markdown]
# Sonstige_autos seems expensive but they are sold in less numbers. Those who buy it might be enthusiasts willing to pay more. The same goes for Mini. Of the top 6 selling brands, bmw, mercedes_benz and audi are expensive. Volkswagen is a cheap option, ford is cheaper and opel is the cheapest option.

# %%
brand_series=pd.Series(unique_brand_counts)

# %%
print(brand_series)
# Out:
# audi               9336
# bmw                8332
# citroen            3779
# fiat               2813
# ford               3749
# hyundai            5365
# mazda              4112
# mercedes_benz      8628
# mini              10613
# nissan             4743
# opel               2975
# peugeot            3094
# renault            2474
# seat               4397
# skoda              6368
# smart              3580
# sonstige_autos    12338
# toyota             5167
# volkswagen         5402
# volvo              4946
# dtype: int64

# %%
brand_df=pd.DataFrame(brand_series, columns=['mean_price'])

# %%
brand_df
# Out:
#                 mean_price
# audi                  9336
# bmw                   8332
# citroen               3779
# fiat                  2813
# ford                  3749
# hyundai               5365
# mazda                 4112
# mercedes_benz         8628
# mini                 10613
# nissan                4743
# opel                  2975
# peugeot               3094
# renault               2474
# seat                  4397
# skoda                 6368
# smart                 3580
# sonstige_autos       12338
# toyota                5167
# volkswagen            5402
# volvo                 4946

# %%
unique_brand_mileage={}
for b in brands_index_sel:
    unique_brand_mileage[b]=int(autos.loc[autos["brand"]==b, "odometer_km"].mean())

# %%
unique_brand_mileage
# Out:
# {'audi': 129157,
#  'bmw': 132572,
#  'citroen': 119694,
#  'fiat': 117121,
#  'ford': 124266,
#  'hyundai': 106442,
#  'mazda': 124464,
#  'mercedes_benz': 130788,
#  'mini': 88105,
#  'nissan': 118330,
#  'opel': 129310,
#  'peugeot': 127153,
#  'renault': 128071,
#  'seat': 121131,
#  'skoda': 110848,
#  'smart': 99326,
#  'sonstige_autos': 89956,
#  'toyota': 115944,
#  'volkswagen': 128707,
#  'volvo': 138067}

# %%
brand_series_mileage=pd.Series(unique_brand_mileage)

# %%
brand_series_mileage
# Out:
# audi              129157
# bmw               132572
# citroen           119694
# fiat              117121
# ford              124266
# hyundai           106442
# mazda             124464
# mercedes_benz     130788
# mini               88105
# nissan            118330
# opel              129310
# peugeot           127153
# renault           128071
# seat              121131
# skoda             110848
# smart              99326
# sonstige_autos     89956
# toyota            115944
# volkswagen        128707
# volvo             138067
# dtype: int64

# %%
brand_df["mileage"]=brand_series_mileage

# %%
brand_df
# Out:
#                 mean_price  mileage
# audi                  9336   129157
# bmw                   8332   132572
# citroen               3779   119694
# fiat                  2813   117121
# ford                  3749   124266
# hyundai               5365   106442
# mazda                 4112   124464
# mercedes_benz         8628   130788
# mini                 10613    88105
# nissan                4743   118330
# opel                  2975   129310
# peugeot               3094   127153
# renault               2474   128071
# seat                  4397   121131
# skoda                 6368   110848
# smart                 3580    99326
# sonstige_autos       12338    89956
# toyota                5167   115944
# volkswagen            5402   128707
# volvo                 4946   138067

# %% [markdown]
# Of the top 6 selling brands, bmw, mercedes_benz and audi are expensive. Volkswagen is a cheap option, ford is cheaper and opel is the cheapest option. This analysis did not change considering the fact that mileage variation is less among them (less than 10%).
